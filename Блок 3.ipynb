# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Прочитайте данные (переменную назовите 'df')
df = pd.read_csv('data.csv')

# Вывести несколько первых строк таблицы данных
print(df.head())
# Out:
#          Дата  Склад Контрагент Номенклатура  Количество
# 0  2018-01-04      1  address_0    product_0           4
# 1  2018-01-04      1  address_0    product_1           4
# 2  2018-01-04      1  address_0    product_2           5
# 3  2018-01-04      1  address_0    product_3          10
# 4  2018-01-04      1  address_0    product_4           2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301355 entries, 0 to 301354
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Дата          301355 non-null  object
#  1   Склад         301355 non-null  int64
#  2   Контрагент    301355 non-null  object
#  3   Номенклатура  301355 non-null  object
#  4   Количество    301355 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 11.5+ MB

# %% [markdown]
# Проверяем формат столбцов

# %%
print(df.dtypes)
# Out:
# Дата            object
# Склад            int64
# Контрагент      object
# Номенклатура    object
# Количество       int64
# dtype: object

# %% [markdown]
# Сразу переведем столбец "Дата" в правильный формат

# %%
df['Дата'] = pd.to_datetime(df['Дата'])

# %% [markdown]
# Сгруппируйте данные по дате, посчитайте количество продаж

# %%
grouped_df = df.groupby('Дата').size()
print(grouped_df)
# Out:
# Дата
# 2018-01-04    1840
# 2018-01-05    1301
# 2018-01-06    1306
# 2018-01-07    1322
# 2018-01-09    1719
#               ...
# 2018-08-26    1462
# 2018-08-28    1731
# 2018-08-29    1497
# 2018-08-30    1445
# 2018-08-31    1366
# Length: 205, dtype: int64

# %% [markdown]
# Вывести несколько первых строк сгруппированных данных

# %%
print(grouped_df.head())
# Out:
# Дата
# 2018-01-04    1840
# 2018-01-05    1301
# 2018-01-06    1306
# 2018-01-07    1322
# 2018-01-09    1719
# dtype: int64

# %% [markdown]
# Нарисуйте график продаж у `grouped_df`

# %%
grouped_df.plot(figsize=(10, 6))
plt.title("График продаж по дате")
plt.xlabel("Дата")
plt.ylabel("Количество продаж")
plt.grid(True)
plt.show()

# %% [markdown]
# Опишите что вы видите на графике. Ваша задача - максимально описать график

# %% [markdown]
# Продажи колебляться в среднем диапозоне от 1400 до 1600. В течении месяцев продажи то высокие то низкие. Спад продаж приходит на март-май месяцы. В остальной периот нормально держиться.

# %% [markdown]
# Найдите строку, у которой максимальный выброс по количеству продаж (нужно найти выброс у `df`)

# %%
max_row = df[df['Количество'] == df['Количество'].max()]
print(max_row)
# Out:
#              Дата  Склад   Контрагент Номенклатура  Количество
# 218822 2018-06-28      1  address_208    product_0         200

# %% [markdown]
# Найдите топовый товар по продажам по средам за июнь, июль, август у 3 склада

# %%
df_filtered = df[(df['Склад'] == 3) & 
                 (df['Дата'].dt.month.isin([6, 7, 8])) & 
                 (df['Дата'].dt.dayofweek == 2)]

top_product = df_filtered.groupby('Номенклатура')['Количество'].sum().idxmax()
print("Топовый товар:", top_product)
# Out:
# Топовый товар: product_1

# %% [markdown]
# Скачайте данные по погоде с https://rp5.ru/Архив_погоды_в_Астане (скачайте исходные данные, и далее преобразуйте так, чтобы мы имели Дату и Среднюю температуру за день), объедините таблицу температуры с `grouped_df`, и нарисуйте график `y=['Количество продаж', 'T']`, где Т это температура. А также отдельно график температуры.

# %%
data = pd.read_excel('data_weather1.xlsx')

# %%
print(data.head())
# Out:
#          Дата     T Unnamed: 2
# 0  2018-08-31   9.6        NaN
# 1  2018-08-31  11.3        NaN
# 2  2018-08-31  12.3        NaN
# 3  2018-08-31  13.2        NaN
# 4  2018-08-31  12.5        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1918 entries, 0 to 1917
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Дата        1918 non-null   object
#  1   T           1918 non-null   float64
#  2   Unnamed: 2  93 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 45.1+ KB

# %%
data['Дата'] = pd.to_datetime(data['Дата'])

# %%
grouped_data = data.groupby('Дата')['T'].mean()
print(grouped_data)
# Out:
# Дата
# 2018-01-04   -13.0875
# 2018-01-05   -17.2500
# 2018-01-06   -14.1250
# 2018-01-07   -12.3375
# 2018-01-08   -15.4375
#                ...
# 2018-08-27    12.2250
# 2018-08-28    14.1000
# 2018-08-29    14.0375
# 2018-08-30    14.1625
# 2018-08-31    11.3875
# Name: T, Length: 240, dtype: float64

# %%
grouped_df = grouped_df.reset_index()
grouped_df.columns = ['Дата', 'Количество']

grouped_data = grouped_data.reset_index()
grouped_data.columns = ['Дата', 'T']

merged_df = pd.merge(grouped_df, grouped_data, on='Дата', how='left')

# %%
plt.figure(figsize=(12, 6))
plt.plot(merged_df['Дата'], merged_df['Количество'], label='Количество продаж', color='b')
plt.plot(merged_df['Дата'], merged_df['T'], label='Температура (T)', color='r')

plt.title("График продаж и температуры по дате")
plt.xlabel("Дата")
plt.ylabel("Значение")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(merged_df['Дата'], merged_df['T'], label='Температура (T)', color='orange')

plt.title("График температуры по дате")
plt.xlabel("Дата")
plt.ylabel("Температура (T)")
plt.grid(True)
plt.show()
